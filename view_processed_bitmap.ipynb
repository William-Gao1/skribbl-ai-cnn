# %%
import numpy as np
import matplotlib.pyplot as plt
import os

target_shape = (64, 64)

scratch = os.path.join(os.path.expanduser('~'), "scratch")
loc = os.path.join(scratch, f"{target_shape[0]}-pre-quickdraw/")

# %%
category = "crown"

category_file = os.path.join(loc, f"{category}.npy")

data =np.load(category_file)

i = 0

# %%
plt.imshow(data[i].reshape(*target_shape), cmap="gray")
i = i + 1
